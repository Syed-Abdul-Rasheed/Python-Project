# %%
# import Libraries
import pandas as pd
import numpy as np
import os

# %%
path=r"C:\Users\abdul\Career-Foundry-Assignment4-Instacart-Basket-Analysis"

# %%
ords_prods_merge=pd.read_pickle(os.path.join(path, '02_Data','Prepared-Data','orders_products_merged_updated.pkl' ))

# %%
df=ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 19)

# %%
df.head(5)
# Out:
#    Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0             0             0   2539329        1    prior             1
# 1             1             1   2398795        1    prior             2
# 2             2             2    473747        1    prior             3
# 3             3             3   2254736        1    prior             4
# 4             4             4    431534        1    prior             5
#
#    order_dow  order_hour_of_day  days_since_prior_order  product_id  \
# 0          2                  8                     7.0         196
# 1          3                  7                    15.0         196
# 2          3                 12                    21.0         196
# 3          4                  7                    29.0         196
# 4          4                 15                    28.0         196
#
#    add_to_cart_order  reordered  Unnamed: 0_y product_name  aisle_id  \
# ...

# %%
df.groupby('product_name')

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').order_number.mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %%
df.groupby('user_id').agg({'order_number': ['max']})
# Out:
#         order_number
#                  max
# user_id
# 1                 10
# 2                 14
# 3                 12
# 5                  4
# 7                 17
# ...              ...
# 206205             1
# 206206            40
# 206207            16
# 206208            49
# 206209             8
#
# [124698 rows x 1 columns]

# %%
ords_prods_merge['max_order']=ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.head(60)
# Out:
#     Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0              0             0   2539329        1    prior             1
# 1              1             1   2398795        1    prior             2
# 2              2             2    473747        1    prior             3
# 3              3             3   2254736        1    prior             4
# 4              4             4    431534        1    prior             5
# 5              5             5   3367565        1    prior             6
# 6              6             6    550135        1    prior             7
# 7              7             7   3108588        1    prior             8
# 8              8             8   2295261        1    prior             9
# 9              9             9   2550362        1    prior            10
# 10           144           144   2968173       15    prior            15
# 11           146           146   1870022       15    prior            17
# ...

# %%
ords_prods_merge.loc[ords_prods_merge['max_order']>40, 'loyalty_flag']='Loyal Customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order']<=40) & (ords_prods_merge['max_order']>10), 'loyalty_flag']='Regular Customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order']<=10, 'loyalty_flag']='New Customer'

# %%
ords_prods_merge.head(15)
# Out:
#     Unnamed: 0.1  Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0              0             0   2539329        1    prior             1
# 1              1             1   2398795        1    prior             2
# 2              2             2    473747        1    prior             3
# 3              3             3   2254736        1    prior             4
# 4              4             4    431534        1    prior             5
# 5              5             5   3367565        1    prior             6
# 6              6             6    550135        1    prior             7
# 7              7             7   3108588        1    prior             8
# 8              8             8   2295261        1    prior             9
# 9              9             9   2550362        1    prior            10
# 10           144           144   2968173       15    prior            15
# 11           146           146   1870022       15    prior            17
# ...

# %%
ords_prods_merge['loyalty_flag'].value_counts()
# Out:
# Regular Customer    15876776
# Loyal Customer      10284093
# New Customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merge[['user_id', 'order_number','max_order','loyalty_flag' ]].head(60)
# Out:
#     user_id  order_number  max_order      loyalty_flag
# 0         1             1         10      New Customer
# 1         1             2         10      New Customer
# 2         1             3         10      New Customer
# 3         1             4         10      New Customer
# 4         1             5         10      New Customer
# 5         1             6         10      New Customer
# 6         1             7         10      New Customer
# 7         1             8         10      New Customer
# 8         1             9         10      New Customer
# 9         1            10         10      New Customer
# 10       15            15         22  Regular Customer
# 11       15            17         22  Regular Customer
# 12       15            18         22  Regular Customer
# 13       15            21         22  Regular Customer
# 14       15            22         22  Regular Customer
# 15       19             2          9      New Customer
# ...
